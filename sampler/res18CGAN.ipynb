# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from resnet18_32x32 import ResNet18_32x32

from torch.utils.data import TensorDataset, DataLoader
import pickle

device = torch.device("cuda" if torch.cuda.is_available() else False)
# Out:
# /root/miniconda3/envs/CGAN/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/root/miniconda3/envs/CGAN/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# 加载保存的label_list
with open('../logs/res/cifar/label_tensor.pickle', 'rb') as f:
    label_list = pickle.load(f)

# 加载保存的probs_list
with open('../logs/res/cifar/probs_tensor.pickle', 'rb') as f:
    probs_list = pickle.load(f)

# %%
#参数加载
latent_dim = 10
lr = 0.0002
batch_size = 1
num_epochs = 200
num_classes = 10

class Generator(nn.Module):
    

    
    def __init__(self, latent_dim, num_classes):
        super(Generator, self).__init__()
        self.label_embed = nn.Embedding(num_classes, latent_dim)
        self.generator = nn.Sequential(
            nn.Linear(latent_dim * 2 , 128),  # 将噪音维度加入生成器输入维度
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, num_classes),
            nn.Softmax(dim=1)
        )

    def forward(self, labels, noise):
        gen_input = self.label_embed(labels)
        gen_input_with_noise = torch.cat((gen_input, noise), -1)  # 将噪音和标签嵌入向量连接起来
        class_probs = self.generator(gen_input_with_noise)
        return class_probs



class Discriminator(nn.Module):
    def __init__(self, num_classes):
        super(Discriminator, self).__init__()
        self.label_embed = nn.Embedding(num_classes, num_classes)
        self.discriminator = nn.Sequential(
            nn.Linear(num_classes * 2 , 512),  # 输入维度为类别数乘以2
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
        

    def forward(self, class_probs, labels):
        label_embed = self.label_embed(labels)
        input_tensor = torch.cat((class_probs, label_embed), dim=1)
        validity = self.discriminator(input_tensor)
        return validity

# %%
# 创建生成器和判别器实例
generator = Generator(latent_dim, num_classes).to(device)
discriminator = Discriminator(num_classes).to(device)

#generator.load_state_dict(torch.load('./lenet/generator200+100.pth'))

#discriminator.load_state_dict(torch.load('./lenet/discriminator200+100.pth'))


# 定义损失函数和优化器
adversarial_loss = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=lr)

optimizer_D = optim.Adam(discriminator.parameters(), lr=lr)

# %%
d_losses = []  # 存储判别器损失值
g_losses = []  # 存储生成器损失值
# 训练生成对抗网络

# 将label_list和probs_list转换为Tensor对象
# 将label_list和probs_list转换为整数类型的Tensor对象
# 将label_list和probs_list转换为Tensor对象
label_tensor = torch.cat(label_list, dim=0)
probs_tensor = torch.cat(probs_list, dim=0)

dataset = TensorDataset(label_tensor, probs_tensor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)


for epoch in range(num_epochs):
    for i, (predicted, probabilities) in enumerate(dataloader):
        # 将数据移动到GPU
        predicted = predicted.to(device)
        probabilities = probabilities.to(device)

        gen_labels = torch.randint(0, num_classes, (batch_size,)).to(device)
        noise = torch.randn(batch_size, latent_dim).to(device)
        gen_class_probs = generator(gen_labels, noise)
        
        
        # 训练判别器
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)
        
        optimizer_D.zero_grad()
        # 判别器判断真实类别概率分布
        real_validity = discriminator(probabilities, predicted)
        real_loss = adversarial_loss(real_validity, real_labels)

        # 判别器判断生成的类别概率分布
        fake_validity = discriminator(gen_class_probs.detach(), gen_labels)
        fake_loss = adversarial_loss(fake_validity, fake_labels)

        d_loss = (real_loss + fake_loss) /2 
        d_loss.backward()
        optimizer_D.step()
        
        
        # 训练生成器
        optimizer_G.zero_grad()

        # 生成器生成类别概率分布，并判别器判断生成的类别概率分布
        gen_validity = discriminator(gen_class_probs, gen_labels)
        g_loss = adversarial_loss(gen_validity, real_labels)

        g_loss.backward()
        optimizer_G.step()

    d_losses.append(d_loss.item())
    g_losses.append(g_loss.item())
    print(f"[Epoch {epoch + 1}/{num_epochs}] Label: {gen_labels}")
    print(f"[Epoch {epoch + 1}/{num_epochs}] Generated Probs: {gen_class_probs.detach().cpu().numpy()}")
    print(f"[Epoch {epoch + 1}/{num_epochs}] D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}")
    if (epoch + 1) % 10 == 0:
        # 保存生成器和判别器的状态字典
        torch.save(generator.state_dict(), f'./res/cifar/1/generator{epoch + 1}.pth')
        torch.save(discriminator.state_dict(), f'./res/cifar/1/discriminator{epoch + 1}.pth')
# Out:
# [Epoch 1/200] Label: tensor([0], device='cuda:0')
# [Epoch 1/200] Generated Probs: [[9.9995649e-01 2.8665406e-09 6.6630737e-06 2.4010720e-05 5.0542135e-06
#   7.5355624e-06 4.9646875e-08 1.7587404e-07 1.7482103e-07 2.3944732e-08]]
# [Epoch 1/200] D Loss: 0.7582, G Loss: 0.5329
# [Epoch 2/200] Label: tensor([1], device='cuda:0')
# [Epoch 2/200] Generated Probs: [[9.0327444e-14 9.9998903e-01 2.4461296e-11 1.3387374e-07 3.7350335e-12
#   5.5724749e-14 7.2368822e-09 1.0376064e-05 4.4830364e-10 4.3837483e-07]]
# [Epoch 2/200] D Loss: 0.3789, G Loss: 0.6399
# [Epoch 3/200] Label: tensor([8], device='cuda:0')
# [Epoch 3/200] Generated Probs: [[2.4568748e-12 1.0204633e-08 1.9597163e-14 4.6900666e-05 8.6081450e-08
#   1.0628789e-03 1.6555949e-05 8.6372147e-06 9.9886489e-01 1.4501108e-08]]
# [Epoch 3/200] D Loss: 0.6963, G Loss: 0.7369
# [Epoch 4/200] Label: tensor([0], device='cuda:0')
# [Epoch 4/200] Generated Probs: [[9.9795258e-01 5.3288179e-05 4.5512381e-04 5.0296984e-04 7.7111495e-04
#   8.4953346e-05 1.0441585e-05 6.4497358e-06 8.2261751e-05 8.0829603e-05]]
# [Epoch 4/200] D Loss: 0.7024, G Loss: 0.6837
# [Epoch 5/200] Label: tensor([0], device='cuda:0')
# [Epoch 5/200] Generated Probs: [[9.9977356e-01 3.3114356e-05 7.5239373e-06 4.8183470e-06 1.4228317e-04
#   3.2821987e-07 1.4739966e-07 1.0297443e-08 1.9756577e-05 1.8472638e-05]]
# [Epoch 5/200] D Loss: 0.8076, G Loss: 0.5657
# [Epoch 6/200] Label: tensor([1], device='cuda:0')
# [Epoch 6/200] Generated Probs: [[1.7436024e-09 9.9966443e-01 1.7714046e-09 1.2836556e-04 2.0368569e-07
#   6.0532647e-12 2.1140925e-06 1.7812573e-07 4.8041962e-09 2.0455831e-04]]
# [Epoch 6/200] D Loss: 0.7362, G Loss: 0.6921
# [Epoch 7/200] Label: tensor([1], device='cuda:0')
# [Epoch 7/200] Generated Probs: [[2.66626557e-07 9.99523282e-01 5.11129639e-10 2.38326962e-07
#   1.59504523e-07 1.21441990e-09 8.74080979e-06 1.39088625e-05
#   8.62229683e-07 4.52555949e-04]]
# [Epoch 7/200] D Loss: 0.7318, G Loss: 0.7174
# [Epoch 8/200] Label: tensor([9], device='cuda:0')
# [Epoch 8/200] Generated Probs: [[1.2834178e-06 5.4804534e-03 3.1795357e-06 3.8253293e-05 3.4783714e-04
#   5.1520663e-05 2.7407392e-05 4.5178981e-06 6.3191779e-05 9.9398226e-01]]
# [Epoch 8/200] D Loss: 0.6346, G Loss: 0.7976
# [Epoch 9/200] Label: tensor([0], device='cuda:0')
# [Epoch 9/200] Generated Probs: [[3.1169480e-01 2.1763539e-02 1.3470327e-02 1.2299939e-02 3.0979378e-02
#   1.5280966e-03 2.8859061e-04 5.8622646e-01 1.9473558e-02 2.2752674e-03]]
# [Epoch 9/200] D Loss: 0.6808, G Loss: 0.7028
# [Epoch 10/200] Label: tensor([1], device='cuda:0')
# [Epoch 10/200] Generated Probs: [[2.8122242e-03 2.0323165e-01 1.6526403e-05 7.8168207e-01 3.1363682e-04
#   1.1995590e-05 7.7289171e-03 3.8410167e-03 2.3953046e-04 1.2237509e-04]]
# [Epoch 10/200] D Loss: 0.6900, G Loss: 0.7042
# [Epoch 11/200] Label: tensor([1], device='cuda:0')
# [Epoch 11/200] Generated Probs: [[4.8009747e-06 9.9943382e-01 9.3973735e-09 3.6972175e-05 6.1854921e-06
#   3.3014086e-08 1.7459114e-04 1.5044103e-05 4.6530072e-06 3.2378195e-04]]
# [Epoch 11/200] D Loss: 0.6922, G Loss: 0.7076
# [Epoch 12/200] Label: tensor([9], device='cuda:0')
# [Epoch 12/200] Generated Probs: [[1.7910131e-04 3.1062295e-03 2.7464557e-05 6.6044078e-05 1.3878032e-04
#   5.8686116e-04 1.5903673e-03 2.3120901e-05 8.3354488e-04 9.9344856e-01]]
# [Epoch 12/200] D Loss: 0.6912, G Loss: 0.6964
# [Epoch 13/200] Label: tensor([3], device='cuda:0')
# [Epoch 13/200] Generated Probs: [[3.8353289e-03 1.4113347e-04 1.9539556e-02 8.4222996e-01 7.6119038e-03
#   6.9548100e-02 4.5936566e-04 5.4608896e-02 1.6625815e-03 3.6322602e-04]]
# [Epoch 13/200] D Loss: 0.7261, G Loss: 0.6895
# [Epoch 14/200] Label: tensor([1], device='cuda:0')
# [Epoch 14/200] Generated Probs: [[1.2703807e-03 9.9658525e-01 3.2896485e-06 8.8256435e-05 2.0614898e-04
#   1.1028630e-07 6.3176136e-05 6.2347845e-06 5.6644413e-04 1.2106916e-03]]
# [Epoch 14/200] D Loss: 0.6946, G Loss: 0.7113
# [Epoch 15/200] Label: tensor([3], device='cuda:0')
# [Epoch 15/200] Generated Probs: [[2.21344298e-09 2.43139509e-09 3.90388523e-05 9.96901631e-01
#   2.25524593e-04 2.77605769e-03 5.35963736e-05 4.11442124e-06
#   1.06187636e-08 1.34907765e-08]]
# [Epoch 15/200] D Loss: 0.6744, G Loss: 0.7083
# [Epoch 16/200] Label: tensor([1], device='cuda:0')
# [Epoch 16/200] Generated Probs: [[4.7315370e-05 8.0764508e-01 9.4832385e-06 2.9644887e-05 1.0355181e-05
#   2.7820748e-08 1.1312696e-03 1.0518242e-05 9.4324176e-05 1.9102205e-01]]
# [Epoch 16/200] D Loss: 0.6927, G Loss: 0.7016
# [Epoch 17/200] Label: tensor([8], device='cuda:0')
# [Epoch 17/200] Generated Probs: [[7.7634846e-05 1.1829431e-05 5.5774720e-08 1.4676314e-06 4.9207260e-10
#   3.8545327e-06 1.9110159e-05 3.2397281e-06 9.9843067e-01 1.4521213e-03]]
# [Epoch 17/200] D Loss: 0.6921, G Loss: 0.6866
# [Epoch 18/200] Label: tensor([5], device='cuda:0')
# [Epoch 18/200] Generated Probs: [[7.8771962e-05 8.3426248e-06 4.6941775e-04 1.5683016e-02 1.6906662e-04
#   9.7027010e-01 1.0701652e-02 1.1595358e-04 1.8195739e-03 6.8410829e-04]]
# [Epoch 18/200] D Loss: 0.6875, G Loss: 0.7052
# [Epoch 19/200] Label: tensor([6], device='cuda:0')
# [Epoch 19/200] Generated Probs: [[1.1778982e-06 3.0115109e-03 6.6942736e-03 5.5054254e-03 3.5453522e-06
#   1.3510829e-04 9.8199308e-01 1.1264785e-05 1.4607401e-03 1.1838563e-03]]
# [Epoch 19/200] D Loss: 0.6906, G Loss: 0.6889
# [Epoch 20/200] Label: tensor([1], device='cuda:0')
# [Epoch 20/200] Generated Probs: [[1.0192513e-03 9.3038255e-01 1.5614889e-04 2.9714811e-03 4.9918774e-04
#   1.4277063e-05 6.8140910e-03 1.4822803e-03 1.1826677e-02 4.4834077e-02]]
# [Epoch 20/200] D Loss: 0.6860, G Loss: 0.6776
# [Epoch 21/200] Label: tensor([4], device='cuda:0')
# [Epoch 21/200] Generated Probs: [[1.3070526e-03 3.3351014e-04 2.7305724e-02 1.1045053e-01 8.0958772e-01
#   3.8697302e-02 4.5273384e-05 4.1775252e-03 5.5054211e-06 8.0898758e-03]]
# [Epoch 21/200] D Loss: 0.7186, G Loss: 0.6639
# [Epoch 22/200] Label: tensor([7], device='cuda:0')
# [Epoch 22/200] Generated Probs: [[8.2276209e-05 3.1261158e-03 6.9312006e-03 1.5784768e-02 1.7251786e-02
#   1.1809127e-03 2.4327601e-03 8.7086105e-01 7.2537565e-05 8.2276635e-02]]
# [Epoch 22/200] D Loss: 0.6702, G Loss: 0.6895
# [Epoch 23/200] Label: tensor([2], device='cuda:0')
# [Epoch 23/200] Generated Probs: [[4.8999763e-03 4.9540718e-06 9.8122782e-01 2.2611961e-04 5.5884151e-03
#   6.3018994e-03 2.9808332e-04 9.9506194e-04 3.9663696e-06 4.5372613e-04]]
# [Epoch 23/200] D Loss: 0.6955, G Loss: 0.7001
# [Epoch 24/200] Label: tensor([0], device='cuda:0')
# [Epoch 24/200] Generated Probs: [[0.66907156 0.00821499 0.0748744  0.0111987  0.05071818 0.00987624
#   0.00372066 0.15445389 0.00865186 0.00921952]]
# [Epoch 24/200] D Loss: 0.6317, G Loss: 0.7413
# [Epoch 25/200] Label: tensor([0], device='cuda:0')
# [Epoch 25/200] Generated Probs: [[9.9235654e-01 4.6209217e-04 3.9719569e-04 5.4056898e-05 9.0158009e-04
#   7.5382617e-05 7.5660268e-05 6.8551127e-04 4.8635444e-03 1.2850303e-04]]
# [Epoch 25/200] D Loss: 0.6944, G Loss: 0.6432
# [Epoch 26/200] Label: tensor([7], device='cuda:0')
# [Epoch 26/200] Generated Probs: [[1.3197913e-04 2.9062989e-04 2.7649005e-05 3.1757627e-03 8.5225340e-04
#   7.7291206e-04 1.2811867e-04 9.9433535e-01 1.9914005e-04 8.6114771e-05]]
# [Epoch 26/200] D Loss: 0.6946, G Loss: 0.7379
# [Epoch 27/200] Label: tensor([5], device='cuda:0')
# [Epoch 27/200] Generated Probs: [[7.4528107e-05 2.5859656e-06 4.1235182e-03 2.8132636e-03 5.4184120e-04
#   9.9186432e-01 2.0019610e-04 2.8956059e-04 5.1160270e-05 3.9027167e-05]]
# [Epoch 27/200] D Loss: 0.6603, G Loss: 0.7604
# [Epoch 28/200] Label: tensor([8], device='cuda:0')
# [Epoch 28/200] Generated Probs: [[1.9307308e-03 3.1457565e-04 9.2631859e-07 6.8755521e-06 1.9362021e-08
#   6.8203878e-04 4.4029159e-04 4.5643399e-05 9.9638283e-01 1.9603508e-04]]
# [Epoch 28/200] D Loss: 0.7135, G Loss: 0.7236
# [Epoch 29/200] Label: tensor([7], device='cuda:0')
# [Epoch 29/200] Generated Probs: [[5.8758189e-04 9.3708746e-05 2.6314601e-04 9.6006179e-04 7.4810593e-04
#   2.1681436e-03 6.4049941e-04 9.9344325e-01 8.3342916e-04 2.6209958e-04]]
# [Epoch 29/200] D Loss: 0.6591, G Loss: 0.6814
# [Epoch 30/200] Label: tensor([9], device='cuda:0')
# [Epoch 30/200] Generated Probs: [[4.2881703e-04 9.8239323e-03 4.9516548e-06 3.1925607e-05 1.8185192e-04
#   1.9798612e-05 5.7082189e-06 7.4114414e-06 6.5455015e-04 9.8884100e-01]]
# [Epoch 30/200] D Loss: 0.6924, G Loss: 0.7087
# [Epoch 31/200] Label: tensor([6], device='cuda:0')
# [Epoch 31/200] Generated Probs: [[6.2354445e-04 1.5802869e-03 2.7810161e-03 1.3253927e-03 1.0482859e-05
#   1.9221408e-03 9.8867083e-01 3.4630342e-04 9.5446658e-04 1.7855165e-03]]
# [Epoch 31/200] D Loss: 0.6321, G Loss: 0.7321
# [Epoch 32/200] Label: tensor([5], device='cuda:0')
# [Epoch 32/200] Generated Probs: [[2.5728758e-04 2.5475126e-06 1.4342304e-03 2.4201175e-02 2.0489176e-03
#   9.6990716e-01 5.6837249e-04 1.2761097e-03 2.4586258e-04 5.8235200e-05]]
# [Epoch 32/200] D Loss: 0.5964, G Loss: 0.7421
# [Epoch 33/200] Label: tensor([7], device='cuda:0')
# [Epoch 33/200] Generated Probs: [[2.0690082e-02 1.9214340e-02 1.2959678e-03 3.6712165e-04 1.0682608e-02
#   2.0245991e-03 7.8751374e-04 9.2173666e-01 1.6549444e-02 6.6516688e-03]]
# [Epoch 33/200] D Loss: 0.7124, G Loss: 0.7501
# [Epoch 34/200] Label: tensor([0], device='cuda:0')
# [Epoch 34/200] Generated Probs: [[9.89329398e-01 8.98246726e-05 1.10351655e-04 7.12912064e-04
#   7.66293705e-03 1.25749051e-04 1.93061487e-06 6.23015003e-05
#   1.52957661e-03 3.75101692e-04]]
# [Epoch 34/200] D Loss: 0.6978, G Loss: 0.7192
# [Epoch 35/200] Label: tensor([9], device='cuda:0')
# [Epoch 35/200] Generated Probs: [[6.4213300e-04 1.5701809e-03 6.7906894e-06 8.5163643e-05 4.1725234e-05
#   1.4074145e-04 1.9216528e-05 1.4429979e-05 7.1169244e-04 9.9676800e-01]]
# [Epoch 35/200] D Loss: 0.6602, G Loss: 0.7090
# [Epoch 36/200] Label: tensor([5], device='cuda:0')
# [Epoch 36/200] Generated Probs: [[8.7693491e-07 1.5768668e-08 3.0889083e-03 1.3343943e-02 4.5983598e-04
#   9.8293316e-01 1.1684402e-04 5.3085318e-05 2.7236831e-06 5.8359331e-07]]
# [Epoch 36/200] D Loss: 0.7380, G Loss: 0.7359
# [Epoch 37/200] Label: tensor([2], device='cuda:0')
# [Epoch 37/200] Generated Probs: [[1.3712352e-02 4.9967557e-04 4.9886474e-01 3.3083826e-02 2.0880574e-01
#   2.3707141e-01 5.7929317e-03 1.6278734e-03 1.3191957e-04 4.0954349e-04]]
# [Epoch 37/200] D Loss: 0.7858, G Loss: 0.5441
# [Epoch 38/200] Label: tensor([0], device='cuda:0')
# [Epoch 38/200] Generated Probs: [[9.9614549e-01 6.2903375e-05 3.0936762e-03 4.9452268e-05 2.1809377e-04
#   8.1108747e-06 4.1466451e-06 1.2828880e-05 1.2744576e-04 2.7780380e-04]]
# [Epoch 38/200] D Loss: 0.6939, G Loss: 0.7145
# [Epoch 39/200] Label: tensor([0], device='cuda:0')
# [Epoch 39/200] Generated Probs: [[9.8313588e-01 6.8013434e-04 4.1720737e-03 8.7798887e-04 3.7544440e-03
#   1.3359092e-03 1.2898771e-04 3.3879941e-04 2.9289513e-03 2.6467897e-03]]
# [Epoch 39/200] D Loss: 0.7212, G Loss: 0.6941
# [Epoch 40/200] Label: tensor([7], device='cuda:0')
# [Epoch 40/200] Generated Probs: [[1.3119202e-03 4.0846394e-06 3.3313065e-06 1.9655787e-05 1.7634875e-04
#   1.3527558e-03 2.6083121e-06 9.9702555e-01 8.8877758e-05 1.4864414e-05]]
# [Epoch 40/200] D Loss: 0.6833, G Loss: 0.7125
# [Epoch 41/200] Label: tensor([2], device='cuda:0')
# [Epoch 41/200] Generated Probs: [[2.1801128e-05 2.6797475e-06 9.9635810e-01 4.3810916e-04 1.2557228e-03
#   1.5391344e-04 1.5864539e-03 1.8274569e-04 2.6942834e-07 1.3583143e-07]]
# [Epoch 41/200] D Loss: 0.6332, G Loss: 0.8233
# [Epoch 42/200] Label: tensor([6], device='cuda:0')
# [Epoch 42/200] Generated Probs: [[1.0326053e-06 8.6467764e-05 1.4503396e-03 1.4060814e-03 1.1530832e-06
#   1.7022909e-05 9.9695075e-01 4.9771243e-06 2.0610069e-06 7.9969002e-05]]
# [Epoch 42/200] D Loss: 0.7218, G Loss: 0.6387
# [Epoch 43/200] Label: tensor([6], device='cuda:0')
# [Epoch 43/200] Generated Probs: [[7.5716986e-07 3.3582073e-05 3.1992753e-05 7.3844254e-05 1.9923128e-07
#   4.7214662e-06 9.9983048e-01 4.8267669e-08 8.6339747e-07 2.3586043e-05]]
# [Epoch 43/200] D Loss: 0.7217, G Loss: 0.6986
# [Epoch 44/200] Label: tensor([2], device='cuda:0')
# [Epoch 44/200] Generated Probs: [[1.2670447e-03 9.9129720e-06 9.8874760e-01 8.2830415e-04 2.4555300e-03
#   2.3659019e-04 6.2055928e-03 2.4712994e-04 3.4347966e-07 1.7952187e-06]]
# [Epoch 44/200] D Loss: 0.7017, G Loss: 0.7222
# [Epoch 45/200] Label: tensor([8], device='cuda:0')
# [Epoch 45/200] Generated Probs: [[2.3363995e-04 3.7987375e-05 6.6936279e-09 1.0411256e-04 1.2635286e-07
#   9.2784125e-05 1.0607071e-05 1.0517899e-04 9.9936444e-01 5.1112827e-05]]
# [Epoch 45/200] D Loss: 0.6935, G Loss: 0.7225
# [Epoch 46/200] Label: tensor([8], device='cuda:0')
# [Epoch 46/200] Generated Probs: [[2.8287740e-03 2.7111892e-04 3.8474255e-09 1.3345576e-07 2.7963495e-08
#   2.5817528e-06 3.6608450e-05 6.9508540e-05 9.9564409e-01 1.1472865e-03]]
# [Epoch 46/200] D Loss: 0.7179, G Loss: 0.7607
# [Epoch 47/200] Label: tensor([2], device='cuda:0')
# [Epoch 47/200] Generated Probs: [[4.8587412e-02 4.9658818e-04 7.3591322e-01 6.0462333e-02 2.0055218e-02
#   2.0301482e-02 2.3860773e-02 8.8677712e-02 1.5988389e-03 4.6415629e-05]]
# [Epoch 47/200] D Loss: 0.7649, G Loss: 0.6239
# [Epoch 48/200] Label: tensor([5], device='cuda:0')
# [Epoch 48/200] Generated Probs: [[2.6191180e-10 3.3841514e-14 1.5477206e-10 2.4997251e-05 4.9906581e-09
#   9.9997497e-01 2.4727601e-10 1.7118779e-09 2.6727706e-08 5.7064981e-11]]
# [Epoch 48/200] D Loss: 0.7207, G Loss: 0.7542
# [Epoch 49/200] Label: tensor([3], device='cuda:0')
# [Epoch 49/200] Generated Probs: [[6.7683706e-18 1.2090498e-11 7.0241044e-09 1.0000000e+00 1.7288021e-10
#   1.7179647e-10 3.6407953e-11 3.2212876e-14 6.5895935e-20 1.0490760e-13]]
# [Epoch 49/200] D Loss: 0.6262, G Loss: 0.8213
# [Epoch 50/200] Label: tensor([6], device='cuda:0')
# [Epoch 50/200] Generated Probs: [[8.1514963e-06 9.1401680e-06 1.6223097e-05 9.6007489e-07 4.9660040e-11
#   1.9731908e-06 9.9996185e-01 1.3578787e-07 1.4526938e-06 6.6217744e-08]]
# [Epoch 50/200] D Loss: 0.7510, G Loss: 0.6680
# [Epoch 51/200] Label: tensor([0], device='cuda:0')
# [Epoch 51/200] Generated Probs: [[9.9498028e-01 8.4586454e-06 2.9590816e-04 6.9707005e-07 1.2317278e-04
#   5.9643287e-07 8.1822909e-05 5.6366879e-08 1.1150892e-06 4.5079640e-03]]
# [Epoch 51/200] D Loss: 0.7470, G Loss: 0.5492
# [Epoch 52/200] Label: tensor([3], device='cuda:0')
# [Epoch 52/200] Generated Probs: [[5.5067699e-07 3.2488501e-06 5.0726123e-02 9.4654936e-01 6.6075527e-06
#   2.0465839e-03 6.5825082e-04 8.9863997e-06 1.2846009e-07 3.5619244e-08]]
# [Epoch 52/200] D Loss: 0.6990, G Loss: 0.6698
# [Epoch 53/200] Label: tensor([3], device='cuda:0')
# [Epoch 53/200] Generated Probs: [[1.2261441e-03 2.0905668e-03 2.3190481e-04 5.5912173e-01 1.5797305e-03
#   4.1569474e-01 8.5423458e-03 1.5027017e-03 5.4585310e-03 4.5516286e-03]]
# [Epoch 53/200] D Loss: 0.7399, G Loss: 0.5296
# [Epoch 54/200] Label: tensor([5], device='cuda:0')
# [Epoch 54/200] Generated Probs: [[4.94794949e-06 1.53345388e-06 3.31937248e-04 1.55423339e-02
#   3.02453467e-04 9.81926501e-01 1.22011674e-03 5.26058429e-04
#   1.11762365e-05 1.32933972e-04]]
# [Epoch 54/200] D Loss: 0.6315, G Loss: 0.7666
# [Epoch 55/200] Label: tensor([4], device='cuda:0')
# [Epoch 55/200] Generated Probs: [[4.2242032e-09 2.1571026e-11 2.8938956e-07 5.6217400e-09 9.9999940e-01
#   3.3633034e-07 1.3063614e-11 9.2961200e-10 1.8134801e-09 1.8095619e-09]]
# [Epoch 55/200] D Loss: 0.6934, G Loss: 0.7148
# [Epoch 56/200] Label: tensor([7], device='cuda:0')
# [Epoch 56/200] Generated Probs: [[1.9345051e-05 1.1318264e-04 2.7617300e-05 3.4081531e-04 1.2439440e-03
#   6.0895534e-04 1.6530255e-04 9.9715650e-01 2.2691309e-04 9.7512901e-05]]
# [Epoch 56/200] D Loss: 0.6785, G Loss: 0.6974
# [Epoch 57/200] Label: tensor([8], device='cuda:0')
# [Epoch 57/200] Generated Probs: [[7.9624369e-05 2.9803296e-05 1.5021170e-08 2.8303257e-08 4.6949578e-09
#   6.2327021e-10 1.8763076e-06 3.2126216e-08 9.9988759e-01 9.9834574e-07]]
# [Epoch 57/200] D Loss: 0.6930, G Loss: 0.7484
# [Epoch 58/200] Label: tensor([5], device='cuda:0')
# [Epoch 58/200] Generated Probs: [[1.8980210e-23 1.4420673e-22 6.8120203e-17 6.1170718e-10 2.1732938e-10
#   1.0000000e+00 1.9817909e-17 2.9583393e-17 1.0591306e-17 7.6606553e-17]]
# [Epoch 58/200] D Loss: 0.6780, G Loss: 0.7408
# [Epoch 59/200] Label: tensor([5], device='cuda:0')
# [Epoch 59/200] Generated Probs: [[2.9494211e-06 5.0663817e-07 7.3535892e-04 7.9364441e-03 1.6656620e-03
#   9.8933733e-01 1.4754880e-04 1.4855096e-04 5.8960104e-06 1.9728859e-05]]
# [Epoch 59/200] D Loss: 0.6952, G Loss: 0.7370
# [Epoch 60/200] Label: tensor([7], device='cuda:0')
# [Epoch 60/200] Generated Probs: [[2.1627182e-10 7.7255102e-08 8.6353573e-09 1.9402418e-07 7.6317492e-06
#   4.7515692e-07 3.2389921e-10 9.9999154e-01 1.8183426e-09 3.4021694e-09]]
# [Epoch 60/200] D Loss: 0.7211, G Loss: 0.6472
# [Epoch 61/200] Label: tensor([6], device='cuda:0')
# [Epoch 61/200] Generated Probs: [[4.4305786e-13 1.8484854e-11 1.2175876e-10 2.4196659e-10 4.3221161e-15
#   7.1424778e-13 1.0000000e+00 2.2351939e-17 5.1869581e-10 3.9423827e-13]]
# [Epoch 61/200] D Loss: 0.6942, G Loss: 0.7404
# [Epoch 62/200] Label: tensor([8], device='cuda:0')
# [Epoch 62/200] Generated Probs: [[2.7508689e-08 3.8168255e-10 2.8485572e-14 7.1338016e-14 1.4835813e-11
#   1.4290659e-12 5.2682286e-10 2.6941019e-17 1.0000000e+00 2.3824638e-08]]
# [Epoch 62/200] D Loss: 0.5873, G Loss: 0.8194
# [Epoch 63/200] Label: tensor([3], device='cuda:0')
# [Epoch 63/200] Generated Probs: [[2.2327492e-16 6.6887668e-10 4.8608606e-10 1.0000000e+00 1.4834452e-15
#   5.7592429e-09 3.8547356e-11 2.2258618e-15 7.1878328e-14 5.6950308e-14]]
# [Epoch 63/200] D Loss: 0.6244, G Loss: 0.9089
# [Epoch 64/200] Label: tensor([3], device='cuda:0')
# [Epoch 64/200] Generated Probs: [[3.9529597e-04 1.2509245e-03 1.0843896e-03 9.1231936e-01 1.7329371e-03
#   6.3264444e-02 8.5674881e-05 1.9551719e-02 1.4058393e-04 1.7467410e-04]]
# [Epoch 64/200] D Loss: 0.7091, G Loss: 0.7372
# [Epoch 65/200] Label: tensor([6], device='cuda:0')
# [Epoch 65/200] Generated Probs: [[5.7544663e-12 3.3244799e-10 4.3180447e-07 1.6353219e-08 6.5028048e-12
#   2.8996085e-13 9.9999952e-01 1.7198273e-16 1.9327186e-11 1.8991423e-12]]
# [Epoch 65/200] D Loss: 0.6978, G Loss: 0.7045
# [Epoch 66/200] Label: tensor([9], device='cuda:0')
# [Epoch 66/200] Generated Probs: [[7.4080119e-05 1.6100126e-03 3.7176406e-10 8.2156075e-05 4.7788885e-06
#   8.1802655e-06 1.9887107e-06 2.0374160e-04 3.0005910e-04 9.9771488e-01]]
# [Epoch 66/200] D Loss: 0.6586, G Loss: 0.6802

# %%
# 可视化损失值
plt.plot(range(1, num_epochs + 1), d_losses, label='Discriminator Loss')

plt.plot(range(1, num_epochs + 1), g_losses, label='Generator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
